# %% [markdown]
# # Statistical Analysis of Ripple(XRP) Coin
#
# Analyst - Sharvari Avhad

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import plotly.express as px
import plotly.graph_objects as go

# %%
xrp = pd.read_csv(r'C:\Users\SHARVARI AVHAD\Downloads\XRP-INR.csv')
xrp
# Out:
#            Date       Open       High        Low      Close  Adj Close  \
# 0    01-07-2020  13.279235  13.475294  13.197317  13.353759  13.353759
# 1    02-07-2020  13.367259  13.319616  13.030086  13.273817  13.273817
# 2    03-07-2020  13.275345  13.335649  13.073013  13.168652  13.168652
# 3    04-07-2020  13.163132  13.418322  13.158214  13.291738  13.291738
# 4    05-07-2020  13.286491  13.347365  13.051222  13.219549  13.219549
# ..          ...        ...        ...        ...        ...        ...
# 361  27-06-2021  45.770954  48.374863  44.357300  48.014915  48.014915
# 362  28-06-2021  48.116009  48.611053  46.407108  47.821117  47.821117
# 363  29-06-2021  47.835606  54.057961  47.717625  52.129616  52.129616
# 364  30-06-2021  52.423542  53.017223  48.274765  52.534092  52.534092
# 365  01-07-2021  52.047630  52.047562  48.733326  49.089664  49.089664
#
#            Volume
# 0    8.420728e+10
# 1    7.891032e+10
# 2    7.293941e+10
# 3    7.469031e+10
# ...

# %%
pd.isnull(xrp['Volume']) #checking for null values
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 361    False
# 362    False
# 363    False
# 364    False
# 365    False
# Name: Volume, Length: 366, dtype: bool

# %%
xrp.dropna() #dropping the rows with null values
# Out:
#            Date       Open       High        Low      Close  Adj Close  \
# 0    01-07-2020  13.279235  13.475294  13.197317  13.353759  13.353759
# 1    02-07-2020  13.367259  13.319616  13.030086  13.273817  13.273817
# 2    03-07-2020  13.275345  13.335649  13.073013  13.168652  13.168652
# 3    04-07-2020  13.163132  13.418322  13.158214  13.291738  13.291738
# 4    05-07-2020  13.286491  13.347365  13.051222  13.219549  13.219549
# ..          ...        ...        ...        ...        ...        ...
# 361  27-06-2021  45.770954  48.374863  44.357300  48.014915  48.014915
# 362  28-06-2021  48.116009  48.611053  46.407108  47.821117  47.821117
# 363  29-06-2021  47.835606  54.057961  47.717625  52.129616  52.129616
# 364  30-06-2021  52.423542  53.017223  48.274765  52.534092  52.534092
# 365  01-07-2021  52.047630  52.047562  48.733326  49.089664  49.089664
#
#            Volume
# 0    8.420728e+10
# 1    7.891032e+10
# 2    7.293941e+10
# 3    7.469031e+10
# ...

# %%
# Extracting Month and Year from 'Date' Column

xrp['Month'] = pd.DatetimeIndex(xrp['Date']).month
xrp['Year'] = pd.DatetimeIndex(xrp['Date']).year
xrp['Month-Year'] = pd.DatetimeIndex(xrp['Date']).strftime('%m-%Y')

# Dropping the extra unrequired column

xrp.drop("Year-Month", axis="columns", inplace=True)

xrp.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close  \
# 0  01-07-2020  13.279235  13.475294  13.197317  13.353759  13.353759
# 1  02-07-2020  13.367259  13.319616  13.030086  13.273817  13.273817
# 2  03-07-2020  13.275345  13.335649  13.073013  13.168652  13.168652
# 3  04-07-2020  13.163132  13.418322  13.158214  13.291738  13.291738
# 4  05-07-2020  13.286491  13.347365  13.051222  13.219549  13.219549
#
#          Volume  month  year  Month  Year Month-Year
# 0  8.420728e+10      1  2020      1  2020    01-2020
# 1  7.891032e+10      2  2020      2  2020    02-2020
# 2  7.293941e+10      3  2020      3  2020    03-2020
# 3  7.469031e+10      4  2020      4  2020    04-2020
# 4  7.241523e+10      5  2020      5  2020    05-2020

# %%
# Line Chart Of Closing Prie 

fig = px.line(xrp, x="Date", y="Close", labels={"Close":"Closing Price"}, title="Closing Price Trend")

fig.show()
# Out:
# <div>                            <div id="d5e4b933-b585-4be3-81b6-ad4e6ba9711d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d5e4b933-b585-4be3-81b6-ad4e6ba9711d")) {                    Plotly.newPlot(                        "d5e4b933-b585-4be3-81b6-ad4e6ba9711d",                        [{"hovertemplate": "Date=%{x}<br>Closing Price=%{y}<extra></extra>", "legendgroup": "", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "", "orientation": "v", "showlegend": false, "type": "scatter", "x": ["01-07-2020", "02-07-2020", "03-07-2020", "04-07-2020", "05-07-2020", "06-07-2020", "07-07-2020", "08-07-2020", "09-07-2020", "10-07-2020", "11-07-2020", "12-07-2020", "13-07-2020", "14-07-2020", "15-07-2020", "16-07-2020", "17-07-2020", 
# ...

# %% [markdown]
# #### This Line graph shows that the Highest value of Ripple(XRP) was achieved in mid of April. The price then was approx 138 INR. This graph also amazes us as the the price of Ripple(XRP) Coin went drastically upwards from July 2020 to April 2021.

# %%
# 

fig = px.bar(xrp, x="Date", y="Volume", title="Volume of Coins being Sold")

fig.show()
# Out:
# <div>                            <div id="ee3be409-0071-4813-873e-35210ad46f5c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ee3be409-0071-4813-873e-35210ad46f5c")) {                    Plotly.newPlot(                        "ee3be409-0071-4813-873e-35210ad46f5c",                        [{"alignmentgroup": "True", "hovertemplate": "Date=%{x}<br>Volume=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["01-07-2020", "02-07-2020", "03-07-2020", "04-07-2020", "05-07-2020", "06-07-2020", "07-07-2020", "08-07-2020", "09-07-2020", "10-07-2020", "11-07-2020", "12-07-2020", "13-07-2020", "14-07-2020", "15-07-2020", "1
# ...

# %%
# Comparison of Open and Close Values for a partcular Month 

fig = px.bar(xrp,
            x = "Month-Year",
            y = ["Open", "Close"],
            barmode = "group",
            title = "Open and Close Values of XRP"
            )
fig.show()
# Out:
# <div>                            <div id="1cfd46cb-fc79-4174-b7ad-68d9698b887a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1cfd46cb-fc79-4174-b7ad-68d9698b887a")) {                    Plotly.newPlot(                        "1cfd46cb-fc79-4174-b7ad-68d9698b887a",                        [{"alignmentgroup": "True", "hovertemplate": "variable=Open<br>Month-Year=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "Open", "marker": {"color": "#636efa"}, "name": "Open", "offsetgroup": "Open", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["01-2020", "02-2020", "03-2020", "04-2020", "05-2020", "06-2020", "07-2020", "08-2020", "09-2020", "10-2020", "11-2020", "12-2020", "07-2020", "07-2020", "07-2020", "07-2020", "07
# ...

# %% [markdown]
# #### This graph shows us that the months in which the Open Value is Higher than the Close Value, there is certain amounth of loss faced by the Investors amd vice versa.
